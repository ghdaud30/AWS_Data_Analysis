# %%
import pandas as pd
import os
import geopandas as gpd
import glob

# os.chdir("/home/ubuntu/real_estate_dashboard")

# 윈도우즈 경로
windows_path = r'C:\Users\ghdau\Desktop\real_estate_dashboard'

# 리눅스 경로로 변환
linux_path = windows_path.replace('\\', '/')

# 작업 디렉토리 변경
os.chdir(linux_path)

print(os.getcwd())

legal_info_b = pd.read_csv("./0_data/legal_info_b.csv",dtype={'법정동코드' : 'str',
                                                              '법정동시군구코드': 'str','법정동읍면동코드':'str'})
legal_info_b
# Out:
# C:\Users\ghdau\Desktop\real_estate_dashboard
#             법정동코드      시도명  시군구명 읍면동명  동리명      생성일자 말소일자 법정동시군구코드 법정동읍면동코드  \
# 0      1111010100    서울특별시   종로구  청운동  NaN  19880423         11110    10100
# 1      1111010200    서울특별시   종로구  신교동  NaN  19880423         11110    10200
# 2      1111010300    서울특별시   종로구  궁정동  NaN  19880423         11110    10300
# 3      1111010400    서울특별시   종로구  효자동  NaN  19880423         11110    10400
# 4      1111010500    서울특별시   종로구  창성동  NaN  19880423         11110    10500
# ...           ...      ...   ...  ...  ...       ...  ...      ...      ...
# 20273  5013032022  제주특별자치도  서귀포시  표선면  하천리  20060701         50130    32022
# 20274  5013032023  제주특별자치도  서귀포시  표선면  성읍리  20060701         50130    32023
# 20275  5013032024  제주특별자치도  서귀포시  표선면  가시리  20060701         50130    32024
# 20276  5013032025  제주특별자치도  서귀포시  표선면  세화리  20060701         50130    32025
# 20277  5013032026  제주특별자치도  서귀포시  표선면  토산리  20060701         50130    32026
#
#                          주소
# 0             서울특별시 종로구 청운동
# 1             서울특별시 종로구 신교동
# 2             서울특별시 종로구 궁정동
# 3             서울특별시 종로구 효자동
# 4             서울특별시 종로구 창성동
# ...                     ...
# 20273  제주특별자치도 서귀포시 표선면 하천리
# 20274  제주특별자치도 서귀포시 표선면 성읍리
# 20275  제주특별자치도 서귀포시 표선면 가시리
# 20276  제주특별자치도 서귀포시 표선면 세화리
# 20277  제주특별자치도 서귀포시 표선면 토산리
#
# [20278 rows x 10 columns]

# %% [markdown]
# ### 법정동 데이터 끝자리에 00 을 더해줘서 지리데이터와 형식을 똑같이 맞춥니다

# %%
legal_info_b['법정동코드_2'] = legal_info_b['법정동코드'].str[:8] + '00'
legal_info_b.head(3)
# Out:
#         법정동코드    시도명 시군구명 읍면동명  동리명      생성일자 말소일자 법정동시군구코드 법정동읍면동코드  \
# 0  1111010100  서울특별시  종로구  청운동  NaN  19880423         11110    10100
# 1  1111010200  서울특별시  종로구  신교동  NaN  19880423         11110    10200
# 2  1111010300  서울특별시  종로구  궁정동  NaN  19880423         11110    10300
#
#               주소     법정동코드_2
# 0  서울특별시 종로구 청운동  1111010100
# 1  서울특별시 종로구 신교동  1111010200
# 2  서울특별시 종로구 궁정동  1111010300

# %% [markdown]
# ### 지리 데이터를 불러옵니다

# %%
geo_data = gpd.read_file('./0_data/geoservice/emd.shp' , encoding='utf-8')
geo_data
# Out:
#         EMD_CD       EMD_ENG_NM       EMD_KOR_NM  \
# 0     11110101    Cheongun-dong  b'c3bbbfeeb5bf'
# 1     11110102      Singyo-dong  b'bdc5b1b3b5bf'
# 2     11110103   Gungjeong-dong  b'b1c3c1a4b5bf'
# 3     11110104       Hyoja-dong  b'c8bfc0dab5bf'
# 4     11110105  Changseong-dong  b'c3a2bcbab5bf'
# ...        ...              ...              ...
# 5060  50130250     Daejeong-eup  b'b4ebc1a4c0be'
# 5061  50130253       Namwon-eup  b'b3b2bff8c0be'
# 5062  50130259     Seongsan-eup  b'bcbabbeac0be'
# 5063  50130310     Andeok-myeon  b'bec8b4f6b8e9'
# 5064  50130320    Pyoseon-myeon  b'c7a5bcb1b8e9'
#
#                                                geometry
# 0     POLYGON ((953700.022 1954605.065, 953693.871 1...
# 1     POLYGON ((953233.465 1953996.984, 953235.183 1...
# 2     POLYGON ((953560.228 1954257.466, 953561.190 1...
# 3     POLYGON ((953519.843 1953890.785, 953518.489 1...
# 4     POLYGON ((953516.123 1953734.362, 953516.526 1...
# ...                                                 ...
# 5060  MULTIPOLYGON (((884996.737 1458754.044, 884991...
# 5061  MULTIPOLYGON (((921259.356 1470626.820, 921220...
# 5062  MULTIPOLYGON (((944514.344 1490162.400, 944510...
# 5063  MULTIPOLYGON (((889476.251 1469109.037, 889465...
# 5064  POLYGON ((938533.676 1481797.427, 938533.718 1...
#
# [5065 rows x 4 columns]

# %%
geo_data.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 5065 entries, 0 to 5064
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EMD_CD      5065 non-null   object
#  1   EMD_ENG_NM  5065 non-null   object
#  2   EMD_KOR_NM  5065 non-null   object
#  3   geometry    5065 non-null   geometry
# dtypes: geometry(1), object(3)
# memory usage: 158.4+ KB

# %%
geo_data.isnull().sum()
# Out:
# EMD_CD        0
# EMD_ENG_NM    0
# EMD_KOR_NM    0
# geometry      0
# dtype: int64

# %%
geo_data['EMD_CD'] = geo_data['EMD_CD'] + '00'
geo_data['EMD_KOR_NM'] = geo_data['EMD_KOR_NM'] .str.decode('euc-kr')

geo_data.rename(columns={'EMD_CD' : '법정동코드_2'} , inplace=True)
geo_data = geo_data[['법정동코드_2','geometry']]
geo_data
# Out:
#          법정동코드_2                                           geometry
# 0     1111010100  POLYGON ((953700.022 1954605.065, 953693.871 1...
# 1     1111010200  POLYGON ((953233.465 1953996.984, 953235.183 1...
# 2     1111010300  POLYGON ((953560.228 1954257.466, 953561.190 1...
# 3     1111010400  POLYGON ((953519.843 1953890.785, 953518.489 1...
# 4     1111010500  POLYGON ((953516.123 1953734.362, 953516.526 1...
# ...          ...                                                ...
# 5060  5013025000  MULTIPOLYGON (((884996.737 1458754.044, 884991...
# 5061  5013025300  MULTIPOLYGON (((921259.356 1470626.820, 921220...
# 5062  5013025900  MULTIPOLYGON (((944514.344 1490162.400, 944510...
# 5063  5013031000  MULTIPOLYGON (((889476.251 1469109.037, 889465...
# 5064  5013032000  POLYGON ((938533.676 1481797.427, 938533.718 1...
#
# [5065 rows x 2 columns]

# %%
geo_data.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 5065 entries, 0 to 5064
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   법정동코드_2   5065 non-null   object
#  1   geometry  5065 non-null   geometry
# dtypes: geometry(1), object(1)
# memory usage: 79.3+ KB

# %% [markdown]
# ### 법정동 데이터와 지리 데이터를 병합 시켜줍니다

# %%
legal_geo_info = pd.merge(legal_info_b, geo_data,
                         on = '법정동코드_2',
                         how = 'left')

print(len(legal_geo_info))
legal_geo_info.head(3).T
# Out:
# 20278
#                                                           0  \
# 법정동코드                                            1111010100
# 시도명                                                   서울특별시
# 시군구명                                                    종로구
# 읍면동명                                                    청운동
# 동리명                                                     NaN
# 생성일자                                               19880423
# 말소일자
# 법정동시군구코드                                              11110
# 법정동읍면동코드                                              10100
# 주소                                            서울특별시 종로구 청운동
# 법정동코드_2                                          1111010100
# geometry  POLYGON ((953700.0221347539 1954605.0654306228...
#
#                                                           1  \
# 법정동코드                                            1111010200
# 시도명                                                   서울특별시
# 시군구명                                                    종로구
# 읍면동명                                                    신교동
# 동리명                                                     NaN
# 생성일자                                               19880423
# 말소일자
# 법정동시군구코드                                              11110
# 법정동읍면동코드                                              10200
# 주소                                            서울특별시 종로구 신교동
# 법정동코드_2                                          1111010200
# geometry  POLYGON ((953233.4654317541 1953996.9839332262...
#
#                                                           2
# 법정동코드                                            1111010300
# 시도명                                                   서울특별시
# 시군구명                                                    종로구
# 읍면동명                                                    궁정동
# 동리명                                                     NaN
# 생성일자                                               19880423
# 말소일자
# 법정동시군구코드                                              11110
# 법정동읍면동코드                                              10300
# 주소                                            서울특별시 종로구 궁정동
# 법정동코드_2                                          1111010300
# geometry  POLYGON ((953560.2281430522 1954257.4664824517...

# %%
# key : 법정동코드
legal_geo_info_2 = legal_geo_info[['법정동코드','시도명','시군구명','동리명','geometry']].drop_duplicates()
print(f'legal_geo_info_2 : {len(legal_geo_info_2)}')

# key : 법정동시군구코드
legal_geo_info_3 = legal_geo_info[['법정동시군구코드','시도명','시군구명']].drop_duplicates()
print(f'legal_geo_info_3 : {len(legal_geo_info_3)}')
# key : 주소
legal_geo_info_4 = legal_geo_info[['주소','법정동코드','법정동읍면동코드','geometry']].drop_duplicates()
print(f'legal_geo_info_4 : {len(legal_geo_info_4)}')
# Out:
# legal_geo_info_2 : 20278
# legal_geo_info_3 : 250
# legal_geo_info_4 : 20278

# %%
# legal_geo_info_2.to_csv(windows_path + "/0_data/legal_geo_info_2.csv",index=False)
# legal_geo_info_3.to_csv(windows_path + "/0_data/legal_geo_info_3.csv",index=False)
# legal_geo_info_4.to_csv(windows_path + "/0_data/legal_geo_info_4.csv",index=False)

# %% [markdown]
# ### 국토교통부 데이터를 처리합니다
# ### 아파트 매매 데이터 전처리

# %%
apt_trade = pd.read_csv('0_data/apt_trade/apt_trade_202101.csv' , thousands=r',')
apt_rent = pd.read_csv('0_data/apt_rent/apt_rent_202101.csv' , thousands=r',')

offi_trade = pd.read_csv('0_data/offi_trade/offi_trade_202101.csv', thousands=r',')
offi_rent = pd.read_csv('0_data/offi_rent/offi_rent_202101.csv', thousands=r',')

print(len(apt_trade))
apt_trade.head(3).T
# Out:
# 60133
#                   0               1          2
# 거래금액         130000          150000     175000
# 거래유형
# 건축년도           2000            2008       2004
# 년              2021            2021       2021
# 도로명         자하문로33길            경희궁길      사직로8길
# 도로명건물본번호코드       43              57         24
# 도로명건물부번호코드        0               0          0
# 도로명시군구코드      11110           11110      11110
# 도로명일련번호코드         1               1          5
# 도로명지상지하코드         0               0          0
# 도로명코드       4100285         4100010    4100135
# 등기일자
# 법정동             청운동             사직동        내수동
# 법정동본번코드        0056            0009       0071
# 법정동부번코드          45               1          0
# 법정동시군구코드      11110           11110      11110
# 법정동읍면동코드      10100           11500      11800
# 법정동지번코드           1               1          1
# 아파트            청운현대  광화문스페이스본(106동)  경희궁의아침2단지
# 월                 1               1          1
# 일                14               7         15
# 일련번호        11110-4      11110-2204  11110-115
# 전용면적         129.76          144.52     174.55
# 중개사소재지
# 지번            56-45             9-1         71
# 지역코드          11110           11110      11110
# 층                 2               6          4

# %%
apt_trade.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60133 entries, 0 to 60132
# Data columns (total 27 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   거래금액        60133 non-null  int64
#  1   거래유형        60133 non-null  object
#  2   건축년도        60133 non-null  int64
#  3   년           60133 non-null  int64
#  4   도로명         60133 non-null  object
#  5   도로명건물본번호코드  60133 non-null  int64
#  6   도로명건물부번호코드  60133 non-null  int64
#  7   도로명시군구코드    60133 non-null  int64
#  8   도로명일련번호코드   60133 non-null  int64
#  9   도로명지상지하코드   60133 non-null  object
#  10  도로명코드       60133 non-null  int64
#  11  등기일자        60133 non-null  object
#  12  법정동         60133 non-null  object
#  13  법정동본번코드     60133 non-null  object
#  14  법정동부번코드     60133 non-null  int64
#  15  법정동시군구코드    60133 non-null  int64
#  16  법정동읍면동코드    60133 non-null  int64
#  17  법정동지번코드     60133 non-null  int64
#  18  아파트         60133 non-null  object
#  19  월           60133 non-null  int64
#  20  일           60133 non-null  int64
#  21  일련번호        60133 non-null  object
#  22  전용면적        60133 non-null  float64
#  23  중개사소재지      60133 non-null  object
#  24  지번          60133 non-null  object
#  25  지역코드        60133 non-null  int64
#  26  층           60133 non-null  int64
# dtypes: float64(1), int64(16), object(10)
# memory usage: 12.4+ MB

# %%
apt_trade.isnull().sum()
# Out:
# 거래금액          0
# 거래유형          0
# 건축년도          0
# 년             0
# 도로명           0
# 도로명건물본번호코드    0
# 도로명건물부번호코드    0
# 도로명시군구코드      0
# 도로명일련번호코드     0
# 도로명지상지하코드     0
# 도로명코드         0
# 등기일자          0
# 법정동           0
# 법정동본번코드       0
# 법정동부번코드       0
# 법정동시군구코드      0
# 법정동읍면동코드      0
# 법정동지번코드       0
# 아파트           0
# 월             0
# 일             0
# 일련번호          0
# 전용면적          0
# 중개사소재지        0
# 지번            0
# 지역코드          0
# 층             0
# dtype: int64

# %% [markdown]
# ### 사용하는 컬럼 만 재정의 해줍니다

# %%
apt_trade['법정동코드'] = apt_trade['법정동시군구코드'].astype(str) + apt_trade['법정동읍면동코드'].astype(str)
apt_trade = apt_trade[['거래금액','거래유형','건축년도','전용면적','법정동','법정동코드','아파트','층','년','월','일']]

print(len(apt_trade))
apt_trade.head(3).T
# Out:
# 60133
#                 0               1           2
# 거래금액       130000          150000      175000
# 거래유형
# 건축년도         2000            2008        2004
# 전용면적       129.76          144.52      174.55
# 법정동           청운동             사직동         내수동
# 법정동코드  1111010100      1111011500  1111011800
# 아파트          청운현대  광화문스페이스본(106동)   경희궁의아침2단지
# 층               2               6           4
# 년            2021            2021        2021
# 월               1               1           1
# 일              14               7          15

# %%
apt_trade.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60133 entries, 0 to 60132
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   거래금액    60133 non-null  int64
#  1   거래유형    60133 non-null  object
#  2   건축년도    60133 non-null  int64
#  3   전용면적    60133 non-null  float64
#  4   법정동     60133 non-null  object
#  5   법정동코드   60133 non-null  object
#  6   아파트     60133 non-null  object
#  7   층       60133 non-null  int64
#  8   년       60133 non-null  int64
#  9   월       60133 non-null  int64
#  10  일       60133 non-null  int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 5.0+ MB

# %%
apt_trade_final = pd.merge(apt_trade,legal_geo_info_2,
                          on = '법정동코드',
                          how ='left')

apt_trade_final
# Out:
#          거래금액 거래유형  건축년도      전용면적      법정동       법정동코드             아파트   층  \
# 0      130000       2000  129.7600      청운동  1111010100            청운현대   2
# 1      150000       2008  144.5200      사직동  1111011500  광화문스페이스본(106동)   6
# 2      175000       2004  174.5500      내수동  1111011800       경희궁의아침2단지   4
# 3      175000       2004  174.5500      내수동  1111011800       경희궁의아침2단지   4
# 4      180000       2004  123.1300      내수동  1111011800       경희궁의아침3단지  13
# ...       ...  ...   ...       ...      ...         ...             ...  ..
# 60128   22800       2015   69.0088  성산읍 고성리  5013025924           드림펠리스   4
# 60129   23000       2017   84.8200  안덕면 화순리  5013031021         엘림피렌체3차   4
# 60130   23000       2017   84.8200  안덕면 화순리  5013031021         엘림피렌체3차   4
# 60131   23000       2017   84.8200  안덕면 화순리  5013031021         엘림피렌체3차   4
# 60132   23000       2017   84.0500  안덕면 화순리  5013031021         엘림피렌체3차   5
#
#           년  월   일      시도명  시군구명  동리명  \
# 0      2021  1  14    서울특별시   종로구  NaN
# 1      2021  1   7    서울특별시   종로구  NaN
# 2      2021  1  15    서울특별시   종로구  NaN
# 3      2021  1  15    서울특별시   종로구  NaN
# 4      2021  1  17    서울특별시   종로구  NaN
# ...     ... ..  ..      ...   ...  ...
# 60128  2021  1  21  제주특별자치도  서귀포시  고성리
# 60129  2021  1  26  제주특별자치도  서귀포시  화순리
# 60130  2021  1  26  제주특별자치도  서귀포시  화순리
# 60131  2021  1  26  제주특별자치도  서귀포시  화순리
# 60132  2021  1  26  제주특별자치도  서귀포시  화순리
#
#                                                 geometry
# 0      POLYGON ((953700.022 1954605.065, 953693.871 1...
# 1      POLYGON ((952745.849 1953334.909, 952758.791 1...
# 2      POLYGON ((953504.696 1952866.960, 953505.697 1...
# 3      POLYGON ((953504.696 1952866.960, 953505.697 1...
# 4      POLYGON ((953504.696 1952866.960, 953505.697 1...
# ...                                                  ...
# 60128  MULTIPOLYGON (((944514.344 1490162.400, 944510...
# 60129  MULTIPOLYGON (((889476.251 1469109.037, 889465...
# 60130  MULTIPOLYGON (((889476.251 1469109.037, 889465...
# 60131  MULTIPOLYGON (((889476.251 1469109.037, 889465...
# 60132  MULTIPOLYGON (((889476.251 1469109.037, 889465...
#
# [60133 rows x 15 columns]

# %%
apt_trade_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60133 entries, 0 to 60132
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   거래금액      60133 non-null  int64
#  1   거래유형      60133 non-null  object
#  2   건축년도      60133 non-null  int64
#  3   전용면적      60133 non-null  float64
#  4   법정동       60133 non-null  object
#  5   법정동코드     60133 non-null  object
#  6   아파트       60133 non-null  object
#  7   층         60133 non-null  int64
#  8   년         60133 non-null  int64
#  9   월         60133 non-null  int64
#  10  일         60133 non-null  int64
#  11  시도명       60133 non-null  object
#  12  시군구명      59678 non-null  object
#  13  동리명       9501 non-null   object
#  14  geometry  60079 non-null  geometry
# dtypes: float64(1), geometry(1), int64(6), object(7)
# memory usage: 6.9+ MB

# %%
apt_trade_final.isnull().sum()
# Out:
# 거래금액            0
# 거래유형            0
# 건축년도            0
# 전용면적            0
# 법정동             0
# 법정동코드           0
# 아파트             0
# 층               0
# 년               0
# 월               0
# 일               0
# 시도명             0
# 시군구명          455
# 동리명         50632
# geometry       54
# dtype: int64

# %%
apt_trade_final[apt_trade_final['시군구명'].isnull()]['시도명'].unique()
# Out:
# array(['세종특별자치시'], dtype=object)

# %% [markdown]
# ### 아파트 전월세 데이터 전처리
# ### 10자리 법정동코드가 없고 대신 지역코드 5자리만 있습니다

# %%
print(len(apt_rent))
apt_rent.head(3).T
# Out:
# 74583
#                       0                    1                    2
# 갱신요구권사용
# 건축년도               2008                 2008                 2008
# 계약구분
# 계약기간
# 년                  2021                 2021                 2021
# 법정동                 사직동                  사직동                  사직동
# 보증금액              20000                 3000                50000
# 아파트      광화문스페이스본(106동)  광화문스페이스본(101동~105동)  광화문스페이스본(101동~105동)
# 월                     1                    1                    1
# 월세금액                280                  300                  150
# 일                     5                    7                    9
# 전용면적              150.4                94.51               108.55
# 종전계약보증금
# 종전계약월세
# 지번                  9-1                    9                    9
# 지역코드              11110                11110                11110
# 층                     5                    9                    1

# %% [markdown]
# ### 1. 지역코드를 이용하여 시도명 시군구명을 얻어옵니다
# ### 2. 시도명과 시군구명 법정동을 더하여 주소 칼럼을 만듭니다
# ### 3. 미리만들어둔 legal_geo_info_4 주소 칼럼을 기준으로 최종 병합 합니다

# %% [markdown]
# ### Step 1

# %%
# 필요한 컬럼만 가져와 재정의 해줍니다
apt_rent = apt_rent[['건축년도','법정동','지번','아파트','보증금액','월세금액','전용면적','층','지역코드','년','월','일']]

apt_rent.rename(columns = {'지역코드':'법정동시군구코드'}, inplace=True)
apt_rent.rename(columns = {'법정동':'동리명'}, inplace=True)

# %%
apt_rent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74583 entries, 0 to 74582
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   건축년도      74583 non-null  int64
#  1   동리명       74583 non-null  object
#  2   지번        74583 non-null  object
#  3   아파트       74583 non-null  object
#  4   보증금액      74583 non-null  int64
#  5   월세금액      74583 non-null  int64
#  6   전용면적      74583 non-null  float64
#  7   층         74583 non-null  int64
#  8   법정동시군구코드  74583 non-null  int64
#  9   년         74583 non-null  int64
#  10  월         74583 non-null  int64
#  11  일         74583 non-null  int64
# dtypes: float64(1), int64(8), object(3)
# memory usage: 6.8+ MB

# %%
apt_rent = apt_rent.astype({'법정동시군구코드':'str'})

apt_rent_2 = pd.merge(apt_rent,legal_geo_info_3,
                    on = '법정동시군구코드',
                     how = 'left')
apt_rent_2
# Out:
#        건축년도      동리명       지번                  아파트    보증금액  월세금액      전용면적  \
# 0      2008      사직동      9-1       광화문스페이스본(106동)   20000   280  150.4000
# 1      2008      사직동        9  광화문스페이스본(101동~105동)    3000   300   94.5100
# 2      2008      사직동        9  광화문스페이스본(101동~105동)   50000   150  108.5500
# 3      2008      사직동        9  광화문스페이스본(101동~105동)   80000     0   70.8000
# 4      2008      사직동        9  광화문스페이스본(101동~105동)  120000     0  158.9900
# ...     ...      ...      ...                  ...     ...   ...       ...
# 74578  2010  대정읍 하모리     1450            서귀포대정휴먼시아    1439    12   46.8000
# 74579  2019  대정읍 하모리  1089-22                 비슬휴림    1000    67   65.8886
# 74580  1996  남원읍 남원리   1323-2                   에덴    7000     0   40.0000
# 74581  2020  성산읍 고성리   1141-1         서귀포성산엘에이치아파트     699    12   26.4400
# 74582  2017  안덕면 화순리     1131              화순블루팰리스   15500     0   73.9403
#
#         층 법정동시군구코드     년  월   일      시도명  시군구명
# 0       5    11110  2021  1   5    서울특별시   종로구
# 1       9    11110  2021  1   7    서울특별시   종로구
# 2       1    11110  2021  1   9    서울특별시   종로구
# 3      12    11110  2021  1   9    서울특별시   종로구
# 4      13    11110  2021  1  12    서울특별시   종로구
# ...    ..      ...   ... ..  ..      ...   ...
# 74578   5    50130  2021  1  18  제주특별자치도  서귀포시
# 74579   5    50130  2021  1  22  제주특별자치도  서귀포시
# 74580   3    50130  2021  1  20  제주특별자치도  서귀포시
# 74581   7    50130  2021  1   2  제주특별자치도  서귀포시
# 74582   2    50130  2021  1   7  제주특별자치도  서귀포시
#
# [74583 rows x 14 columns]

# %% [markdown]
# ### Step 2

# %%
#  먼저 각 컬럼에 공백을 제거해줍니다
apt_rent_2['시도명'] = apt_rent_2['시도명'].str.strip()
apt_rent_2['시군구명'] = apt_rent_2['시군구명'].str.strip()
apt_rent_2['동리명'] = apt_rent_2['동리명'].str.strip()

apt_rent_2['주소'] = apt_rent_2['시도명'] + " " + apt_rent_2['시군구명'] + " " + apt_rent_2['동리명']

# %% [markdown]
# ### Step 3

# %%
apt_rent_3 = pd.merge(apt_rent_2, legal_geo_info_4,
                     on = '주소',
                     how = 'left')
apt_rent_3
# Out:
#        건축년도      동리명       지번                  아파트    보증금액  월세금액      전용면적  \
# 0      2008      사직동      9-1       광화문스페이스본(106동)   20000   280  150.4000
# 1      2008      사직동        9  광화문스페이스본(101동~105동)    3000   300   94.5100
# 2      2008      사직동        9  광화문스페이스본(101동~105동)   50000   150  108.5500
# 3      2008      사직동        9  광화문스페이스본(101동~105동)   80000     0   70.8000
# 4      2008      사직동        9  광화문스페이스본(101동~105동)  120000     0  158.9900
# ...     ...      ...      ...                  ...     ...   ...       ...
# 74578  2010  대정읍 하모리     1450            서귀포대정휴먼시아    1439    12   46.8000
# 74579  2019  대정읍 하모리  1089-22                 비슬휴림    1000    67   65.8886
# 74580  1996  남원읍 남원리   1323-2                   에덴    7000     0   40.0000
# 74581  2020  성산읍 고성리   1141-1         서귀포성산엘에이치아파트     699    12   26.4400
# 74582  2017  안덕면 화순리     1131              화순블루팰리스   15500     0   73.9403
#
#         층 법정동시군구코드     년  월   일      시도명  시군구명                    주소  \
# 0       5    11110  2021  1   5    서울특별시   종로구         서울특별시 종로구 사직동
# 1       9    11110  2021  1   7    서울특별시   종로구         서울특별시 종로구 사직동
# 2       1    11110  2021  1   9    서울특별시   종로구         서울특별시 종로구 사직동
# 3      12    11110  2021  1   9    서울특별시   종로구         서울특별시 종로구 사직동
# 4      13    11110  2021  1  12    서울특별시   종로구         서울특별시 종로구 사직동
# ...    ..      ...   ... ..  ..      ...   ...                   ...
# 74578   5    50130  2021  1  18  제주특별자치도  서귀포시  제주특별자치도 서귀포시 대정읍 하모리
# 74579   5    50130  2021  1  22  제주특별자치도  서귀포시  제주특별자치도 서귀포시 대정읍 하모리
# 74580   3    50130  2021  1  20  제주특별자치도  서귀포시  제주특별자치도 서귀포시 남원읍 남원리
# 74581   7    50130  2021  1   2  제주특별자치도  서귀포시  제주특별자치도 서귀포시 성산읍 고성리
# 74582   2    50130  2021  1   7  제주특별자치도  서귀포시  제주특별자치도 서귀포시 안덕면 화순리
#
#             법정동코드 법정동읍면동코드                                           geometry
# 0      1111011500    11500  POLYGON ((952745.849 1953334.909, 952758.791 1...
# 1      1111011500    11500  POLYGON ((952745.849 1953334.909, 952758.791 1...
# 2      1111011500    11500  POLYGON ((952745.849 1953334.909, 952758.791 1...
# 3      1111011500    11500  POLYGON ((952745.849 1953334.909, 952758.791 1...
# 4      1111011500    11500  POLYGON ((952745.849 1953334.909, 952758.791 1...
# ...           ...      ...                                                ...
# 74578  5013025022    25022  MULTIPOLYGON (((884996.737 1458754.044, 884991...
# 74579  5013025022    25022  MULTIPOLYGON (((884996.737 1458754.044, 884991...
# 74580  5013025321    25321  MULTIPOLYGON (((921259.356 1470626.820, 921220...
# 74581  5013025924    25924  MULTIPOLYGON (((944514.344 1490162.400, 944510...
# 74582  5013031021    31021  MULTIPOLYGON (((889476.251 1469109.037, 889465...
#
# [74583 rows x 18 columns]

# %%
apt_rent_3.isnull().sum()
# Out:
# 건축년도           0
# 동리명            0
# 지번             0
# 아파트            0
# 보증금액           0
# 월세금액           0
# 전용면적           0
# 층              0
# 법정동시군구코드       0
# 년              0
# 월              0
# 일              0
# 시도명            0
# 시군구명        1121
# 주소          1121
# 법정동코드       1145
# 법정동읍면동코드    1145
# geometry    1154
# dtype: int64

# %% [markdown]
# ### 하지만 병합을 하고 보니 법정동코드에 공백 컬럼이 보입니다

# %%
apt_rent_3[apt_rent_3['법정동코드'].isnull()]
# Out:
#        건축년도     동리명   지번                 아파트   보증금액  월세금액     전용면적   층  \
# 34882  2017     소담동  598   새샘마을5단지(한양수자인엘시티)  20000     0  59.4544   8
# 34883  2017     소담동  598   새샘마을5단지(한양수자인엘시티)  18000     0  84.6347  17
# 34884  2017     소담동  598   새샘마을5단지(한양수자인엘시티)   2000    70  59.4544  11
# 34885  2016     소담동  521  새샘마을9단지(중흥S클래스리버뷰)  37000     0  84.9779  15
# 34886  2017     보람동  783     호려울마을5단지(제일풍경채)  40000     0  99.9860  10
# ...     ...     ...  ...                 ...    ...   ...      ...  ..
# 58834  2020  북문로3가동  123        청주행정타운코아루휴티스  29000     0  84.6871  34
# 58835  2020  북문로3가동  123        청주행정타운코아루휴티스  25000     0  84.6871   9
# 58836  2020  북문로3가동  123        청주행정타운코아루휴티스  25000     0  84.6871  47
# 58837  2016  남문로1가동   53                트레비앙   1000    30  22.5400   9
# 58838  2016  남문로1가동   53                트레비앙   1500    25  25.2000   6
#
#       법정동시군구코드     년  월   일      시도명     시군구명                   주소 법정동코드  \
# 34882    36110  2021  1  20  세종특별자치시      NaN                  NaN   NaN
# 34883    36110  2021  1  22  세종특별자치시      NaN                  NaN   NaN
# 34884    36110  2021  1  27  세종특별자치시      NaN                  NaN   NaN
# 34885    36110  2021  1  28  세종특별자치시      NaN                  NaN   NaN
# 34886    36110  2021  1   2  세종특별자치시      NaN                  NaN   NaN
# ...        ...   ... ..  ..      ...      ...                  ...   ...
# 58834    43111  2021  1  30     충청북도  청주시 상당구  충청북도 청주시 상당구 북문로3가동   NaN
# 58835    43111  2021  1  30     충청북도  청주시 상당구  충청북도 청주시 상당구 북문로3가동   NaN
# 58836    43111  2021  1  31     충청북도  청주시 상당구  충청북도 청주시 상당구 북문로3가동   NaN
# 58837    43111  2021  1  20     충청북도  청주시 상당구  충청북도 청주시 상당구 남문로1가동   NaN
# 58838    43111  2021  1  21     충청북도  청주시 상당구  충청북도 청주시 상당구 남문로1가동   NaN
#
#       법정동읍면동코드 geometry
# 34882      NaN     None
# 34883      NaN     None
# 34884      NaN     None
# 34885      NaN     None
# 34886      NaN     None
# ...        ...      ...
# 58834      NaN     None
# 58835      NaN     None
# 58836      NaN     None
# 58837      NaN     None
# 58838      NaN     None
#
# [1145 rows x 18 columns]

# %%
apt_rent_3[apt_rent_3['법정동코드'].isnull()][['주소','시도명']]
# Out:
#                         주소      시도명
# 34882                  NaN  세종특별자치시
# 34883                  NaN  세종특별자치시
# 34884                  NaN  세종특별자치시
# 34885                  NaN  세종특별자치시
# 34886                  NaN  세종특별자치시
# ...                    ...      ...
# 58834  충청북도 청주시 상당구 북문로3가동     충청북도
# 58835  충청북도 청주시 상당구 북문로3가동     충청북도
# 58836  충청북도 청주시 상당구 북문로3가동     충청북도
# 58837  충청북도 청주시 상당구 남문로1가동     충청북도
# 58838  충청북도 청주시 상당구 남문로1가동     충청북도
#
# [1145 rows x 2 columns]

# %% [markdown]
# ### 세종특별자치시와 충청북도 칼럼이 문제입니다

# %%
apt_rent_3[apt_rent_3['법정동코드'].isnull()][['주소','시도명']].drop_duplicates()
# Out:
#                         주소      시도명
# 34882                  NaN  세종특별자치시
# 58815  충청북도 청주시 상당구 북문로2가동     충청북도
# 58818  충청북도 청주시 상당구 북문로3가동     충청북도
# 58837  충청북도 청주시 상당구 남문로1가동     충청북도

# %% [markdown]
# ### 세종특별자치시는 시군구명 값이 없습니다

# %%
apt_rent_3[apt_rent_3['법정동시군구코드'] == '36110']
# Out:
#        건축년도      동리명      지번                 아파트   보증금액  월세금액     전용면적   층  \
# 34882  2017      소담동     598   새샘마을5단지(한양수자인엘시티)  20000     0  59.4544   8
# 34883  2017      소담동     598   새샘마을5단지(한양수자인엘시티)  18000     0  84.6347  17
# 34884  2017      소담동     598   새샘마을5단지(한양수자인엘시티)   2000    70  59.4544  11
# 34885  2016      소담동     521  새샘마을9단지(중흥S클래스리버뷰)  37000     0  84.9779  15
# 34886  2017      보람동     783     호려울마을5단지(제일풍경채)  40000     0  99.9860  10
# ...     ...      ...     ...                 ...    ...   ...      ...  ..
# 35998  2000  금남면 용포리     320               두진리버빌    300    32  43.0080  14
# 35999  2002  장군면 금암리   259-1         영조정보마을임대아파트   3200     0  28.2616   1
# 36000  1992  전의면 동교리  197-16                  재동   4500     0  59.8700   5
# 36001  1991  전의면 동교리   121-6            재동(1,2동)   5000     0  59.8800   1
# 36002  1996  소정면 운당리    35-1                 무궁화   4000     0  59.4000   2
#
#       법정동시군구코드     년  월   일      시도명 시군구명   주소 법정동코드 법정동읍면동코드 geometry
# 34882    36110  2021  1  20  세종특별자치시  NaN  NaN   NaN      NaN     None
# 34883    36110  2021  1  22  세종특별자치시  NaN  NaN   NaN      NaN     None
# 34884    36110  2021  1  27  세종특별자치시  NaN  NaN   NaN      NaN     None
# 34885    36110  2021  1  28  세종특별자치시  NaN  NaN   NaN      NaN     None
# 34886    36110  2021  1   2  세종특별자치시  NaN  NaN   NaN      NaN     None
# ...        ...   ... ..  ..      ...  ...  ...   ...      ...      ...
# 35998    36110  2021  1  27  세종특별자치시  NaN  NaN   NaN      NaN     None
# 35999    36110  2021  1   6  세종특별자치시  NaN  NaN   NaN      NaN     None
# 36000    36110  2021  1  20  세종특별자치시  NaN  NaN   NaN      NaN     None
# 36001    36110  2021  1  22  세종특별자치시  NaN  NaN   NaN      NaN     None
# 36002    36110  2021  1  20  세종특별자치시  NaN  NaN   NaN      NaN     None
#
# [1121 rows x 18 columns]

# %%
apt_rent_2.where(pd.notnull(apt_rent_2),'')
# Out:
#        건축년도      동리명       지번                  아파트    보증금액  월세금액      전용면적  \
# 0      2008      사직동      9-1       광화문스페이스본(106동)   20000   280  150.4000
# 1      2008      사직동        9  광화문스페이스본(101동~105동)    3000   300   94.5100
# 2      2008      사직동        9  광화문스페이스본(101동~105동)   50000   150  108.5500
# 3      2008      사직동        9  광화문스페이스본(101동~105동)   80000     0   70.8000
# 4      2008      사직동        9  광화문스페이스본(101동~105동)  120000     0  158.9900
# ...     ...      ...      ...                  ...     ...   ...       ...
# 74578  2010  대정읍 하모리     1450            서귀포대정휴먼시아    1439    12   46.8000
# 74579  2019  대정읍 하모리  1089-22                 비슬휴림    1000    67   65.8886
# 74580  1996  남원읍 남원리   1323-2                   에덴    7000     0   40.0000
# 74581  2020  성산읍 고성리   1141-1         서귀포성산엘에이치아파트     699    12   26.4400
# 74582  2017  안덕면 화순리     1131              화순블루팰리스   15500     0   73.9403
#
#         층 법정동시군구코드     년  월   일      시도명  시군구명                    주소
# 0       5    11110  2021  1   5    서울특별시   종로구         서울특별시 종로구 사직동
# 1       9    11110  2021  1   7    서울특별시   종로구         서울특별시 종로구 사직동
# 2       1    11110  2021  1   9    서울특별시   종로구         서울특별시 종로구 사직동
# 3      12    11110  2021  1   9    서울특별시   종로구         서울특별시 종로구 사직동
# 4      13    11110  2021  1  12    서울특별시   종로구         서울특별시 종로구 사직동
# ...    ..      ...   ... ..  ..      ...   ...                   ...
# 74578   5    50130  2021  1  18  제주특별자치도  서귀포시  제주특별자치도 서귀포시 대정읍 하모리
# 74579   5    50130  2021  1  22  제주특별자치도  서귀포시  제주특별자치도 서귀포시 대정읍 하모리
# 74580   3    50130  2021  1  20  제주특별자치도  서귀포시  제주특별자치도 서귀포시 남원읍 남원리
# 74581   7    50130  2021  1   2  제주특별자치도  서귀포시  제주특별자치도 서귀포시 성산읍 고성리
# 74582   2    50130  2021  1   7  제주특별자치도  서귀포시  제주특별자치도 서귀포시 안덕면 화순리
#
# [74583 rows x 15 columns]

# %%
apt_rent_2['시도명'] = apt_rent_2['시도명'].str.strip()
apt_rent_2['시군구명'] = apt_rent_2['시군구명'].str.strip()
apt_rent_2['동리명'] = apt_rent_2['동리명'].str.strip()

apt_rent_2 = apt_rent_2.where(pd.notnull(apt_rent_2),'')

apt_rent_2['주소'] = apt_rent_2['시도명'] + " " + apt_rent_2['시군구명'] + " " + apt_rent_2['동리명']

apt_rent_2['주소'] = apt_rent_2['주소'].str.replace('  ',' ')
apt_rent_2['주소'] = apt_rent_2['주소'].str.strip()

# %%
apt_rent_3 = pd.merge(apt_rent_2, legal_geo_info_4,
                     on = '주소',
                     how = 'left')
apt_rent_3
# Out:
#        건축년도      동리명       지번                  아파트    보증금액  월세금액      전용면적  \
# 0      2008      사직동      9-1       광화문스페이스본(106동)   20000   280  150.4000
# 1      2008      사직동        9  광화문스페이스본(101동~105동)    3000   300   94.5100
# 2      2008      사직동        9  광화문스페이스본(101동~105동)   50000   150  108.5500
# 3      2008      사직동        9  광화문스페이스본(101동~105동)   80000     0   70.8000
# 4      2008      사직동        9  광화문스페이스본(101동~105동)  120000     0  158.9900
# ...     ...      ...      ...                  ...     ...   ...       ...
# 74578  2010  대정읍 하모리     1450            서귀포대정휴먼시아    1439    12   46.8000
# 74579  2019  대정읍 하모리  1089-22                 비슬휴림    1000    67   65.8886
# 74580  1996  남원읍 남원리   1323-2                   에덴    7000     0   40.0000
# 74581  2020  성산읍 고성리   1141-1         서귀포성산엘에이치아파트     699    12   26.4400
# 74582  2017  안덕면 화순리     1131              화순블루팰리스   15500     0   73.9403
#
#         층 법정동시군구코드     년  월   일      시도명  시군구명                    주소  \
# 0       5    11110  2021  1   5    서울특별시   종로구         서울특별시 종로구 사직동
# 1       9    11110  2021  1   7    서울특별시   종로구         서울특별시 종로구 사직동
# 2       1    11110  2021  1   9    서울특별시   종로구         서울특별시 종로구 사직동
# 3      12    11110  2021  1   9    서울특별시   종로구         서울특별시 종로구 사직동
# 4      13    11110  2021  1  12    서울특별시   종로구         서울특별시 종로구 사직동
# ...    ..      ...   ... ..  ..      ...   ...                   ...
# 74578   5    50130  2021  1  18  제주특별자치도  서귀포시  제주특별자치도 서귀포시 대정읍 하모리
# 74579   5    50130  2021  1  22  제주특별자치도  서귀포시  제주특별자치도 서귀포시 대정읍 하모리
# 74580   3    50130  2021  1  20  제주특별자치도  서귀포시  제주특별자치도 서귀포시 남원읍 남원리
# 74581   7    50130  2021  1   2  제주특별자치도  서귀포시  제주특별자치도 서귀포시 성산읍 고성리
# 74582   2    50130  2021  1   7  제주특별자치도  서귀포시  제주특별자치도 서귀포시 안덕면 화순리
#
#             법정동코드 법정동읍면동코드                                           geometry
# 0      1111011500    11500  POLYGON ((952745.849 1953334.909, 952758.791 1...
# 1      1111011500    11500  POLYGON ((952745.849 1953334.909, 952758.791 1...
# 2      1111011500    11500  POLYGON ((952745.849 1953334.909, 952758.791 1...
# 3      1111011500    11500  POLYGON ((952745.849 1953334.909, 952758.791 1...
# 4      1111011500    11500  POLYGON ((952745.849 1953334.909, 952758.791 1...
# ...           ...      ...                                                ...
# 74578  5013025022    25022  MULTIPOLYGON (((884996.737 1458754.044, 884991...
# 74579  5013025022    25022  MULTIPOLYGON (((884996.737 1458754.044, 884991...
# 74580  5013025321    25321  MULTIPOLYGON (((921259.356 1470626.820, 921220...
# 74581  5013025924    25924  MULTIPOLYGON (((944514.344 1490162.400, 944510...
# 74582  5013031021    31021  MULTIPOLYGON (((889476.251 1469109.037, 889465...
#
# [74583 rows x 18 columns]

# %%
apt_rent_3[apt_rent_3['법정동코드'].isnull()].drop_duplicates()
# Out:
#        건축년도     동리명     지번           아파트   보증금액  월세금액     전용면적   층 법정동시군구코드  \
# 58815  2016  북문로2가동  78-10      아트에비뉴198    200    30  18.9750   8    43111
# 58816  2016  북문로2가동  78-10      아트에비뉴198    300    30  18.9750   7    43111
# 58817  2016  북문로2가동  78-10      아트에비뉴198    300    30  21.8670  12    43111
# 58818  2020  북문로3가동    123  청주행정타운코아루휴티스  28000     0  84.9935  27    43111
# 58819  2020  북문로3가동    123  청주행정타운코아루휴티스   3000    70  84.9935  20    43111
# 58820  2020  북문로3가동    123  청주행정타운코아루휴티스  30000     0  84.9935  28    43111
# 58821  2020  북문로3가동    123  청주행정타운코아루휴티스  29000     0  84.9935  31    43111
# 58822  2020  북문로3가동    123  청주행정타운코아루휴티스  26000     0  84.9935   8    43111
# 58823  2020  북문로3가동    123  청주행정타운코아루휴티스  27000     0  84.9935  20    43111
# 58824  2020  북문로3가동    123  청주행정타운코아루휴티스  25000     0  84.6871  19    43111
# 58825  2013  북문로3가동   49-1     북문로한신휴플러스  16000     0  84.9904   5    43111
# 58826  2020  북문로3가동    123  청주행정타운코아루휴티스  25000     0  84.9935  18    43111
# 58827  2013  북문로3가동   49-1     북문로한신휴플러스   3000    80  84.9888  17    43111
# 58829  2020  북문로3가동    123  청주행정타운코아루휴티스  28000     0  84.6871  49    43111
# 58830  2020  북문로3가동    123  청주행정타운코아루휴티스   9000     0  84.9935   4    43111
# 58831  2020  북문로3가동    123  청주행정타운코아루휴티스  26000     0  84.9935  25    43111
# 58832  2020  북문로3가동    123  청주행정타운코아루휴티스  28500     0  84.9935  44    43111
# 58833  2020  북문로3가동    123  청주행정타운코아루휴티스  25000     0  84.9935  20    43111
# 58834  2020  북문로3가동    123  청주행정타운코아루휴티스  29000     0  84.6871  34    43111
# 58835  2020  북문로3가동    123  청주행정타운코아루휴티스  25000     0  84.6871   9    43111
# 58836  2020  북문로3가동    123  청주행정타운코아루휴티스  25000     0  84.6871  47    43111
# 58837  2016  남문로1가동     53          트레비앙   1000    30  22.5400   9    43111
# 58838  2016  남문로1가동     53          트레비앙   1500    25  25.2000   6    43111
#
#           년  월   일   시도명     시군구명                   주소 법정동코드 법정동읍면동코드 geometry
# 58815  2021  1   7  충청북도  청주시 상당구  충청북도 청주시 상당구 북문로2가동   NaN      NaN     None
# 58816  2021  1  16  충청북도  청주시 상당구  충청북도 청주시 상당구 북문로2가동   NaN      NaN     None
# 58817  2021  1  17  충청북도  청주시 상당구  충청북도 청주시 상당구 북문로2가동   NaN      NaN     None
# 58818  2021  1   4  충청북도  청주시 상당구  충청북도 청주시 상당구 북문로3가동   NaN      NaN     None
# 58819  2021  1  12  충청북도  청주시 상당구  충청북도 청주시 상당구 북문로3가동   NaN      NaN     None
# 58820  2021  1  14  충청북도  청주시 상당구  충청북도 청주시 상당구 북문로3가동   NaN      NaN     None
# 58821  2021  1  14  충청북도  청주시 상당구  충청북도 청주시 상당구 북문로3가동   NaN      NaN     None
# 58822  2021  1  17  충청북도  청주시 상당구  충청북도 청주시 상당구 북문로3가동   NaN      NaN     None
# 58823  2021  1  18  충청북도  청주시 상당구  충청북도 청주시 상당구 북문로3가동   NaN      NaN     None
# 58824  2021  1  18  충청북도  청주시 상당구  충청북도 청주시 상당구 북문로3가동   NaN      NaN     None
# 58825  2021  1  22  충청북도  청주시 상당구  충청북도 청주시 상당구 북문로3가동   NaN      NaN     None
# 58826  2021  1  23  충청북도  청주시 상당구  충청북도 청주시 상당구 북문로3가동   NaN      NaN     None
# 58827  2021  1  23  충청북도  청주시 상당구  충청북도 청주시 상당구 북문로3가동   NaN      NaN     None
# 58829  2021  1  25  충청북도  청주시 상당구  충청북도 청주시 상당구 북문로3가동   NaN      NaN     None
# 58830  2021  1  25  충청북도  청주시 상당구  충청북도 청주시 상당구 북문로3가동   NaN      NaN     None
# 58831  2021  1  25  충청북도  청주시 상당구  충청북도 청주시 상당구 북문로3가동   NaN      NaN     None
# 58832  2021  1  25  충청북도  청주시 상당구  충청북도 청주시 상당구 북문로3가동   NaN      NaN     None
# 58833  2021  1  30  충청북도  청주시 상당구  충청북도 청주시 상당구 북문로3가동   NaN      NaN     None
# 58834  2021  1  30  충청북도  청주시 상당구  충청북도 청주시 상당구 북문로3가동   NaN      NaN     None
# 58835  2021  1  30  충청북도  청주시 상당구  충청북도 청주시 상당구 북문로3가동   NaN      NaN     None
# 58836  2021  1  31  충청북도  청주시 상당구  충청북도 청주시 상당구 북문로3가동   NaN      NaN     None
# 58837  2021  1  20  충청북도  청주시 상당구  충청북도 청주시 상당구 남문로1가동   NaN      NaN     None
# 58838  2021  1  21  충청북도  청주시 상당구  충청북도 청주시 상당구 남문로1가동   NaN      NaN     None

# %% [markdown]
# ### 충청북도 청주시 상당구 뒤에 동이 없기때문에 수정해줍니다

# %%
apt_rent_2 = apt_rent_2.replace('충청북도 청주시 상당구 북문로2가동','충청북도 청주시 상당구 북문로2가')
apt_rent_2 = apt_rent_2.replace('충청북도 청주시 상당구 북문로3가동','충청북도 청주시 상당구 북문로3가')
apt_rent_2 = apt_rent_2.replace('충청북도 청주시 상당구 남문로1가동','충청북도 청주시 상당구 남문로1가')

# %% [markdown]
# ### 수정된 데이터 프레임을 다시 병합해보면 문제가 없음을 알 수 있습니다

# %%
apt_rent_3 = pd.merge(apt_rent_2, legal_geo_info_4,
                     on = '주소',
                     how = 'left')
apt_rent_3
# Out:
#        건축년도      동리명       지번                  아파트    보증금액  월세금액      전용면적  \
# 0      2008      사직동      9-1       광화문스페이스본(106동)   20000   280  150.4000
# 1      2008      사직동        9  광화문스페이스본(101동~105동)    3000   300   94.5100
# 2      2008      사직동        9  광화문스페이스본(101동~105동)   50000   150  108.5500
# 3      2008      사직동        9  광화문스페이스본(101동~105동)   80000     0   70.8000
# 4      2008      사직동        9  광화문스페이스본(101동~105동)  120000     0  158.9900
# ...     ...      ...      ...                  ...     ...   ...       ...
# 74578  2010  대정읍 하모리     1450            서귀포대정휴먼시아    1439    12   46.8000
# 74579  2019  대정읍 하모리  1089-22                 비슬휴림    1000    67   65.8886
# 74580  1996  남원읍 남원리   1323-2                   에덴    7000     0   40.0000
# 74581  2020  성산읍 고성리   1141-1         서귀포성산엘에이치아파트     699    12   26.4400
# 74582  2017  안덕면 화순리     1131              화순블루팰리스   15500     0   73.9403
#
#         층 법정동시군구코드     년  월   일      시도명  시군구명                    주소  \
# 0       5    11110  2021  1   5    서울특별시   종로구         서울특별시 종로구 사직동
# 1       9    11110  2021  1   7    서울특별시   종로구         서울특별시 종로구 사직동
# 2       1    11110  2021  1   9    서울특별시   종로구         서울특별시 종로구 사직동
# 3      12    11110  2021  1   9    서울특별시   종로구         서울특별시 종로구 사직동
# 4      13    11110  2021  1  12    서울특별시   종로구         서울특별시 종로구 사직동
# ...    ..      ...   ... ..  ..      ...   ...                   ...
# 74578   5    50130  2021  1  18  제주특별자치도  서귀포시  제주특별자치도 서귀포시 대정읍 하모리
# 74579   5    50130  2021  1  22  제주특별자치도  서귀포시  제주특별자치도 서귀포시 대정읍 하모리
# 74580   3    50130  2021  1  20  제주특별자치도  서귀포시  제주특별자치도 서귀포시 남원읍 남원리
# 74581   7    50130  2021  1   2  제주특별자치도  서귀포시  제주특별자치도 서귀포시 성산읍 고성리
# 74582   2    50130  2021  1   7  제주특별자치도  서귀포시  제주특별자치도 서귀포시 안덕면 화순리
#
#             법정동코드 법정동읍면동코드                                           geometry
# 0      1111011500    11500  POLYGON ((952745.849 1953334.909, 952758.791 1...
# 1      1111011500    11500  POLYGON ((952745.849 1953334.909, 952758.791 1...
# 2      1111011500    11500  POLYGON ((952745.849 1953334.909, 952758.791 1...
# 3      1111011500    11500  POLYGON ((952745.849 1953334.909, 952758.791 1...
# 4      1111011500    11500  POLYGON ((952745.849 1953334.909, 952758.791 1...
# ...           ...      ...                                                ...
# 74578  5013025022    25022  MULTIPOLYGON (((884996.737 1458754.044, 884991...
# 74579  5013025022    25022  MULTIPOLYGON (((884996.737 1458754.044, 884991...
# 74580  5013025321    25321  MULTIPOLYGON (((921259.356 1470626.820, 921220...
# 74581  5013025924    25924  MULTIPOLYGON (((944514.344 1490162.400, 944510...
# 74582  5013031021    31021  MULTIPOLYGON (((889476.251 1469109.037, 889465...
#
# [74583 rows x 18 columns]

# %%
apt_rent_3[apt_rent_3['법정동시군구코드'] == '36110']
# Out:
#        건축년도      동리명      지번                 아파트   보증금액  월세금액     전용면적   층  \
# 34882  2017      소담동     598   새샘마을5단지(한양수자인엘시티)  20000     0  59.4544   8
# 34883  2017      소담동     598   새샘마을5단지(한양수자인엘시티)  18000     0  84.6347  17
# 34884  2017      소담동     598   새샘마을5단지(한양수자인엘시티)   2000    70  59.4544  11
# 34885  2016      소담동     521  새샘마을9단지(중흥S클래스리버뷰)  37000     0  84.9779  15
# 34886  2017      보람동     783     호려울마을5단지(제일풍경채)  40000     0  99.9860  10
# ...     ...      ...     ...                 ...    ...   ...      ...  ..
# 35998  2000  금남면 용포리     320               두진리버빌    300    32  43.0080  14
# 35999  2002  장군면 금암리   259-1         영조정보마을임대아파트   3200     0  28.2616   1
# 36000  1992  전의면 동교리  197-16                  재동   4500     0  59.8700   5
# 36001  1991  전의면 동교리   121-6            재동(1,2동)   5000     0  59.8800   1
# 36002  1996  소정면 운당리    35-1                 무궁화   4000     0  59.4000   2
#
#       법정동시군구코드     년  월   일      시도명 시군구명               주소       법정동코드  \
# 34882    36110  2021  1  20  세종특별자치시           세종특별자치시 소담동  3611010200
# 34883    36110  2021  1  22  세종특별자치시           세종특별자치시 소담동  3611010200
# 34884    36110  2021  1  27  세종특별자치시           세종특별자치시 소담동  3611010200
# 34885    36110  2021  1  28  세종특별자치시           세종특별자치시 소담동  3611010200
# 34886    36110  2021  1   2  세종특별자치시           세종특별자치시 보람동  3611010300
# ...        ...   ... ..  ..      ...  ...              ...         ...
# 35998    36110  2021  1  27  세종특별자치시       세종특별자치시 금남면 용포리  3611034021
# 35999    36110  2021  1   6  세종특별자치시       세종특별자치시 장군면 금암리  3611035025
# 36000    36110  2021  1  20  세종특별자치시       세종특별자치시 전의면 동교리  3611037022
# 36001    36110  2021  1  22  세종특별자치시       세종특별자치시 전의면 동교리  3611037022
# 36002    36110  2021  1  20  세종특별자치시       세종특별자치시 소정면 운당리  3611039022
#
#       법정동읍면동코드                                           geometry
# 34882    10200  POLYGON ((982515.836 1832329.682, 982521.520 1...
# 34883    10200  POLYGON ((982515.836 1832329.682, 982521.520 1...
# 34884    10200  POLYGON ((982515.836 1832329.682, 982521.520 1...
# 34885    10200  POLYGON ((982515.836 1832329.682, 982521.520 1...
# 34886    10300  POLYGON ((981533.190 1831957.290, 981530.993 1...
# ...        ...                                                ...
# 35998    34021  POLYGON ((987548.917 1832590.855, 987513.919 1...
# 35999    35025  POLYGON ((976668.256 1832051.548, 976681.266 1...
# 36000    37022  POLYGON ((972819.479 1845225.865, 972814.966 1...
# 36001    37022  POLYGON ((972819.479 1845225.865, 972814.966 1...
# 36002    39022  POLYGON ((973916.009 1857927.157, 973906.880 1...
#
# [1121 rows x 18 columns]

# %%
apt_rent_3[apt_rent_3['법정동코드'].isnull()].drop_duplicates()
# Out:
# Empty DataFrame
# Columns: [건축년도, 동리명, 지번, 아파트, 보증금액, 월세금액, 전용면적, 층, 법정동시군구코드, 년, 월, 일, 시도명, 시군구명, 주소, 법정동코드, 법정동읍면동코드, geometry]
# Index: []

# %% [markdown]
# ### 다른 데이터 컬럼도 살펴보겠습니다

# %%
print(offi_trade.columns)
print(offi_rent.columns)
# Out:
# Index(['거래금액', '거래유형', '건축년도', '년', '단지', '법정동', '시군구', '월', '일', '전용면적',
#        '중개사소재지', '지번', '지역코드', '층'],
#       dtype='object')
# Index(['갱신요구권사용', '건축년도', '계약구분', '계약기간', '년', '단지', '법정동', '보증금', '시군구', '월',
#        '월세', '일', '전용면적', '종전계약보증금', '종전계약월세', '지번', '지역코드', '층'],
#       dtype='object')

# %% [markdown]
# ### 나머지 데이터는 아파트 전월세 데이터 처럼 지역코드가 있는 경우 이므로
# ### 함수를 구현하여 빠르게 전처리를 하겠습니다

# %%
def molit_data_cleaning(df,df_name):
    
    # 아파트 실거래 매매 데이터 인 경우
    if('법정동시군구코드' in df.columns):
        print(df_name)
        df = df.astype({'법정동시군구코드' : 'str',
                        '법정동읍면동코드' : 'str'})
        df['법정동코드'] = df['법정동시군구코드'] + df['법정동읍면동코드']
        df = df[['거래금액','거래유형','건축년도','전용면적','법정동','법정동코드','아파트',
                '층','년','월','일']]
        
        df_final = pd.merge(df,legal_geo_info_2,
                           on = '법정동코드',
                           how = 'left')
        
        print('-' * 100)
        print(df_final.isnull().sum())
        print()
        
    # 아파트 실거래 매매 제외 전부    
    else:
        print(df_name)
        # 칼럼 이름 변경
        df.rename(columns={'지역코드':'법정동시군구코드'},inplace=True)
        df.rename(columns={'법정동':'동리명'},inplace=True)
        
        # 칼럼 자료형 변경
        df = df.astype({'법정동시군구코드' : 'str'})
        
        # 키 값 = 법정동시군구코드
        df = pd.merge(df,legal_geo_info_3,
                     on = '법정동시군구코드',
                     how = 'left')
        
        # 컬럼 양쪽 공백 제거
        df['시도명'] = df['시도명'].str.strip()
        df['시군구명'] = df['시군구명'].str.strip()
        df['동리명'] = df['동리명'].str.strip()
        
        # Nan 값을 공백으로 변경
        df = df.where(pd.notnull(df),'')
        
        # 주소 컬럼 추가
        df['주소'] = df['시도명'] + " " + df['시군구명'] + " " + df['동리명']

        # 주소 칼럼 공백 2개 부분을 1개로 변경
        # 주소 양쪽 공백 제거
        df['주소'] = df['주소'].str.replace('  ',' ')
        df['주소'] = df['주소'].str.strip()
        
        # 예외 문자열 변경
        df = df.replace('충청북도 청주시 상당구 북문로2가동','충청북도 청주시 상당구 북문로2가')
        df = df.replace('충청북도 청주시 상당구 북문로3가동','충청북도 청주시 상당구 북문로3가')
        df = df.replace('충청북도 청주시 상당구 남문로1가동','충청북도 청주시 상당구 남문로1가')
        
        # 최종 병합 키 값은 주소
        df_final = pd.merge(df, legal_geo_info_4,
                     on = '주소',
                     how = 'left')
        
        # 결측값을 가진 행 제거
        df_final = df_final.dropna()
        
        print('-' * 100)
        print(df_final.isnull().sum())
        print()
        
    return df_final

# %% [markdown]
# ### 각 데이터에 함수가 에러가 없는지 테스트 해봅니다

# %%
apt_trade = pd.read_csv('0_data/apt_trade/apt_trade_202103.csv' , thousands=r',')
apt_rent = pd.read_csv('0_data/apt_rent/apt_rent_202103.csv' , thousands=r',')

offi_trade = pd.read_csv('0_data/offi_trade/offi_trade_202103.csv', thousands=r',')
offi_rent = pd.read_csv('0_data/offi_rent/offi_rent_202103.csv', thousands=r',')

datas = [apt_trade,apt_rent,offi_trade,offi_rent]
names = ['아파트 매매','아파트 전월세','오피스텔 매매','오피스텔 전월세']
# Out:
# C:\Users\ghdau\AppData\Local\Temp\ipykernel_20264\3263170928.py:1: DtypeWarning: Columns (14,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   apt_trade = pd.read_csv('0_data/apt_trade/apt_trade_202103.csv' , thousands=r',')

# %%
for data , name in zip(datas,names):
    df_clean = molit_data_cleaning(data, name)
    if(name !=  '아파트 매매'):
        print(df_clean[df_clean['법정동코드'].isnull()])
# Out:
# 아파트 매매
# ----------------------------------------------------------------------------------------------------
# 거래금액            0
# 거래유형            0
# 건축년도            0
# 전용면적            0
# 법정동             0
# 법정동코드           0
# 아파트             0
# 층               0
# 년               0
# 월               0
# 일               0
# 시도명             0
# 시군구명          407
# 동리명         49719
# geometry       23
# dtype: int64
#
# 아파트 전월세
# ----------------------------------------------------------------------------------------------------
# 갱신요구권사용     0
# 건축년도        0
# 계약구분        0
# 계약기간        0
# 년           0
# 동리명         0
# 보증금액        0
# 아파트         0
# 월           0
# 월세금액        0
# 일           0
# 전용면적        0
# 종전계약보증금     0
# 종전계약월세      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# Empty DataFrame
# Columns: [갱신요구권사용, 건축년도, 계약구분, 계약기간, 년, 동리명, 보증금액, 아파트, 월, 월세금액, 일, 전용면적, 종전계약보증금, 종전계약월세, 지번, 법정동시군구코드, 층, 시도명, 시군구명, 주소, 법정동코드, 법정동읍면동코드, geometry]
# Index: []
#
# [0 rows x 23 columns]
# 오피스텔 매매
# ----------------------------------------------------------------------------------------------------
# 거래금액        0
# 거래유형        0
# 건축년도        0
# 년           0
# 단지          0
# 동리명         0
# 시군구         0
# 월           0
# 일           0
# 전용면적        0
# 중개사소재지      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# Empty DataFrame
# Columns: [거래금액, 거래유형, 건축년도, 년, 단지, 동리명, 시군구, 월, 일, 전용면적, 중개사소재지, 지번, 법정동시군구코드, 층, 시도명, 시군구명, 주소, 법정동코드, 법정동읍면동코드, geometry]
# Index: []
# 오피스텔 전월세
# ----------------------------------------------------------------------------------------------------
# 갱신요구권사용     0
# 건축년도        0
# 계약구분        0
# 계약기간        0
# 년           0
# 단지          0
# 동리명         0
# 보증금         0
# 시군구         0
# 월           0
# 월세          0
# 일           0
# 전용면적        0
# 종전계약보증금     0
# 종전계약월세      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# Empty DataFrame
# Columns: [갱신요구권사용, 건축년도, 계약구분, 계약기간, 년, 단지, 동리명, 보증금, 시군구, 월, 월세, 일, 전용면적, 종전계약보증금, 종전계약월세, 지번, 법정동시군구코드, 층, 시도명, 시군구명, 주소, 법정동코드, 법정동읍면동코드, geometry]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# ### 데이터 저장

# %%
# 테스트
apt_trade_test = molit_data_cleaning(apt_trade,'아파트 매매')
print(apt_trade_test.shape)
# Out:
# 아파트 매매
# ----------------------------------------------------------------------------------------------------
# 거래금액            0
# 거래유형            0
# 건축년도            0
# 전용면적            0
# 법정동             0
# 법정동코드           0
# 아파트             0
# 층               0
# 년               0
# 월               0
# 일               0
# 시도명             0
# 시군구명          407
# 동리명         49719
# geometry       23
# dtype: int64
#
# (59731, 15)

# %% [markdown]
# ### 지리 정보 때문에 데이터에 크기가 많이 나옵니다

# %%
# file_name = windows_path + '/0_data/cleaning/apt_trade_test.csv'
# # file_name = '/0_data/cleaning/apt_trade_test.csv''

# apt_trade_test.to_csv(file_name,index = False)

# %% [markdown]
# ### 지리 정보를 제거하고 저장해 보겠습니다

# %%
apt_trade_test_rm_geometry = molit_data_cleaning(apt_trade,'아파트 매매')
apt_trade_test_rm_geometry = apt_trade_test_rm_geometry.drop(columns =['geometry'])

file_name = windows_path + '/0_data/cleaning/apt_trade_test_rm_geometry.csv'
# file_name = '/0_data/cleaning/apt_trade_test_rm_geometry.csv''

# apt_trade_test_rm_geometry.to_csv(file_name,index = False)
# Out:
# 아파트 매매
# ----------------------------------------------------------------------------------------------------
# 거래금액            0
# 거래유형            0
# 건축년도            0
# 전용면적            0
# 법정동             0
# 법정동코드           0
# 아파트             0
# 층               0
# 년               0
# 월               0
# 일               0
# 시도명             0
# 시군구명          407
# 동리명         49719
# geometry       23
# dtype: int64

# %% [markdown]
# ### geometry 칼럼 문제 해결
#
# ### 1. 수집한 모든 데이터를 함수를 통해 전처리 해줍니다
# ### 2. 전처리후 geomtery 칼럼을 제거한후 이어 붙입니다
# ### 3. 이어 붙인 데이터는 0_data/cleaning/에 하나씩 저장 합니다

# %%
import time

# 실행 전 시간 기록
start_time = time.time()

# 국토교통부 데이터 세트
list_nm =['apt_trade','apt_rent','offi_trade','offi_rent']
names = ['아파트 매매','아파트 전월세','오피스텔 매매','오피스텔 전월세']

# 4개 데이터 세트 반복문
for i in range(len(list_nm)):
    
    total = pd.DataFrame()
    
    # 각 타입별 모든 데이터 조회
    dir_list = linux_path + f'/0_data/{list_nm[i]}/*.csv'
    file_list = sorted(glob.glob(dir_list))
    file_list = [file.replace('\\', '/') for file in file_list]
    
    for k in range(len(file_list)):
        print(k)
        df = pd.read_csv(file_list[k], thousands=r',')
        
        clean_df = molit_data_cleaning(df,names[i])
        clean_df = clean_df.drop(columns=['geometry'])
        
        total = pd.concat([total,clean_df])
    
    file_name = linux_path + f'/0_data/cleaning/{list_nm[i]}.csv'
    total.to_csv(file_name, index = False)
    
# 실행 후 시간 기록
end_time = time.time()  

# 실행 시간 계산
execution_time = end_time - start_time
print(f"실행 시간: {execution_time} 초")
# Out:
# 0
# 아파트 매매
# ----------------------------------------------------------------------------------------------------
# 거래금액            0
# 거래유형            0
# 건축년도            0
# 전용면적            0
# 법정동             0
# 법정동코드           0
# 아파트             0
# 층               0
# 년               0
# 월               0
# 일               0
# 시도명             0
# 시군구명          455
# 동리명         50632
# geometry       54
# dtype: int64
#
# 1
# C:\Users\ghdau\AppData\Local\Temp\ipykernel_20264\1985241356.py:22: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_list[k], thousands=r',')
# 아파트 매매
# ----------------------------------------------------------------------------------------------------
# 거래금액            0
# 거래유형            0
# 건축년도            0
# 전용면적            0
# 법정동             0
# 법정동코드           0
# 아파트             0
# 층               0
# 년               0
# 월               0
# 일               0
# 시도명             0
# 시군구명          375
# 동리명         42413
# geometry       24
# dtype: int64
#
# 2
# C:\Users\ghdau\AppData\Local\Temp\ipykernel_20264\1985241356.py:22: DtypeWarning: Columns (14,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_list[k], thousands=r',')
# 아파트 매매
# ----------------------------------------------------------------------------------------------------
# 거래금액            0
# 거래유형            0
# 건축년도            0
# 전용면적            0
# 법정동             0
# 법정동코드           0
# 아파트             0
# 층               0
# 년               0
# 월               0
# 일               0
# 시도명             0
# 시군구명          407
# 동리명         49719
# geometry       23
# dtype: int64
#
# 3
# C:\Users\ghdau\AppData\Local\Temp\ipykernel_20264\1985241356.py:22: DtypeWarning: Columns (5,6,7,8,10,13,14,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_list[k], thousands=r',')
# 아파트 매매
# ----------------------------------------------------------------------------------------------------
# 거래금액            0
# 거래유형            0
# 건축년도            0
# 전용면적            0
# 법정동             0
# 법정동코드           0
# 아파트             0
# 층               0
# 년               0
# 월               0
# 일               0
# 시도명             0
# 시군구명          334
# 동리명         43530
# geometry       25
# dtype: int64
#
# 4
# C:\Users\ghdau\AppData\Local\Temp\ipykernel_20264\1985241356.py:22: DtypeWarning: Columns (5,6,7,10,14,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_list[k], thousands=r',')
# 아파트 매매
# ----------------------------------------------------------------------------------------------------
# 거래금액            0
# 거래유형            0
# 건축년도            0
# 전용면적            0
# 법정동             0
# 법정동코드           0
# 아파트             0
# 층               0
# 년               0
# 월               0
# 일               0
# 시도명             0
# 시군구명          342
# 동리명         47858
# geometry       16
# dtype: int64
#
# 5
# C:\Users\ghdau\AppData\Local\Temp\ipykernel_20264\1985241356.py:22: DtypeWarning: Columns (5,6,7,10,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_list[k], thousands=r',')
# 아파트 매매
# ----------------------------------------------------------------------------------------------------
# 거래금액            0
# 거래유형            0
# 건축년도            0
# 전용면적            0
# 법정동             0
# 법정동코드           0
# 아파트             0
# 층               0
# 년               0
# 월               0
# 일               0
# 시도명             0
# 시군구명          166
# 동리명         42964
# geometry        8
# dtype: int64
#
# 6
# C:\Users\ghdau\AppData\Local\Temp\ipykernel_20264\1985241356.py:22: DtypeWarning: Columns (5,6,7,10,14,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_list[k], thousands=r',')
# 아파트 매매
# ----------------------------------------------------------------------------------------------------
# 거래금액            0
# 거래유형            0
# 건축년도            0
# 전용면적            0
# 법정동             0
# 법정동코드           0
# 아파트             0
# 층               0
# 년               0
# 월               0
# 일               0
# 시도명             0
# 시군구명          238
# 동리명         47684
# geometry       18
# dtype: int64
#
# 7
# C:\Users\ghdau\AppData\Local\Temp\ipykernel_20264\1985241356.py:22: DtypeWarning: Columns (5,6,7,10,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_list[k], thousands=r',')
# 아파트 매매
# ----------------------------------------------------------------------------------------------------
# 거래금액            0
# 거래유형            0
# 건축년도            0
# 전용면적            0
# 법정동             0
# 법정동코드           0
# 아파트             0
# 층               0
# 년               0
# 월               0
# 일               0
# 시도명             0
# 시군구명          330
# 동리명         44331
# geometry        7
# dtype: int64
#
# 8
# C:\Users\ghdau\AppData\Local\Temp\ipykernel_20264\1985241356.py:22: DtypeWarning: Columns (5,6,7,10,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_list[k], thousands=r',')
# 아파트 매매
# ----------------------------------------------------------------------------------------------------
# 거래금액            0
# 거래유형            0
# 건축년도            0
# 전용면적            0
# 법정동             0
# 법정동코드           0
# 아파트             0
# 층               0
# 년               0
# 월               0
# 일               0
# 시도명             0
# 시군구명          284
# 동리명         35025
# geometry        8
# dtype: int64
#
# 0
# 아파트 전월세
# ----------------------------------------------------------------------------------------------------
# 갱신요구권사용     0
# 건축년도        0
# 계약구분        0
# 계약기간        0
# 년           0
# 동리명         0
# 보증금액        0
# 아파트         0
# 월           0
# 월세금액        0
# 일           0
# 전용면적        0
# 종전계약보증금     0
# 종전계약월세      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 1
# 아파트 전월세
# ----------------------------------------------------------------------------------------------------
# 갱신요구권사용     0
# 건축년도        0
# 계약구분        0
# 계약기간        0
# 년           0
# 동리명         0
# 보증금액        0
# 아파트         0
# 월           0
# 월세금액        0
# 일           0
# 전용면적        0
# 종전계약보증금     0
# 종전계약월세      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 2
# 아파트 전월세
# ----------------------------------------------------------------------------------------------------
# 갱신요구권사용     0
# 건축년도        0
# 계약구분        0
# 계약기간        0
# 년           0
# 동리명         0
# 보증금액        0
# 아파트         0
# 월           0
# 월세금액        0
# 일           0
# 전용면적        0
# 종전계약보증금     0
# 종전계약월세      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 3
# 아파트 전월세
# ----------------------------------------------------------------------------------------------------
# 갱신요구권사용     0
# 건축년도        0
# 계약구분        0
# 계약기간        0
# 년           0
# 동리명         0
# 보증금액        0
# 아파트         0
# 월           0
# 월세금액        0
# 일           0
# 전용면적        0
# 종전계약보증금     0
# 종전계약월세      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 4
# 아파트 전월세
# ----------------------------------------------------------------------------------------------------
# 갱신요구권사용     0
# 건축년도        0
# 계약구분        0
# 계약기간        0
# 년           0
# 동리명         0
# 보증금액        0
# 아파트         0
# 월           0
# 월세금액        0
# 일           0
# 전용면적        0
# 종전계약보증금     0
# 종전계약월세      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 5
# 아파트 전월세
# ----------------------------------------------------------------------------------------------------
# 갱신요구권사용     0
# 건축년도        0
# 계약구분        0
# 계약기간        0
# 년           0
# 동리명         0
# 보증금액        0
# 아파트         0
# 월           0
# 월세금액        0
# 일           0
# 전용면적        0
# 종전계약보증금     0
# 종전계약월세      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 6
# 아파트 전월세
# ----------------------------------------------------------------------------------------------------
# 갱신요구권사용     0
# 건축년도        0
# 계약구분        0
# 계약기간        0
# 년           0
# 동리명         0
# 보증금액        0
# 아파트         0
# 월           0
# 월세금액        0
# 일           0
# 전용면적        0
# 종전계약보증금     0
# 종전계약월세      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 7
# 아파트 전월세
# ----------------------------------------------------------------------------------------------------
# 갱신요구권사용     0
# 건축년도        0
# 계약구분        0
# 계약기간        0
# 년           0
# 동리명         0
# 보증금액        0
# 아파트         0
# 월           0
# 월세금액        0
# 일           0
# 전용면적        0
# 종전계약보증금     0
# 종전계약월세      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 8
# 아파트 전월세
# ----------------------------------------------------------------------------------------------------
# 갱신요구권사용     0
# 건축년도        0
# 계약구분        0
# 계약기간        0
# 년           0
# 동리명         0
# 보증금액        0
# 아파트         0
# 월           0
# 월세금액        0
# 일           0
# 전용면적        0
# 종전계약보증금     0
# 종전계약월세      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 9
# 아파트 전월세
# ----------------------------------------------------------------------------------------------------
# 갱신요구권사용     0
# 건축년도        0
# 계약구분        0
# 계약기간        0
# 년           0
# 동리명         0
# 보증금액        0
# 아파트         0
# 월           0
# 월세금액        0
# 일           0
# 전용면적        0
# 종전계약보증금     0
# 종전계약월세      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 10
# 아파트 전월세
# ----------------------------------------------------------------------------------------------------
# 갱신요구권사용     0
# 건축년도        0
# 계약구분        0
# 계약기간        0
# 년           0
# 동리명         0
# 보증금액        0
# 아파트         0
# 월           0
# 월세금액        0
# 일           0
# 전용면적        0
# 종전계약보증금     0
# 종전계약월세      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 0
# 오피스텔 매매
# ----------------------------------------------------------------------------------------------------
# 거래금액        0
# 거래유형        0
# 건축년도        0
# 년           0
# 단지          0
# 동리명         0
# 시군구         0
# 월           0
# 일           0
# 전용면적        0
# 중개사소재지      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 1
# 오피스텔 매매
# ----------------------------------------------------------------------------------------------------
# 거래금액        0
# 거래유형        0
# 건축년도        0
# 년           0
# 단지          0
# 동리명         0
# 시군구         0
# 월           0
# 일           0
# 전용면적        0
# 중개사소재지      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 2
# 오피스텔 매매
# ----------------------------------------------------------------------------------------------------
# 거래금액        0
# 거래유형        0
# 건축년도        0
# 년           0
# 단지          0
# 동리명         0
# 시군구         0
# 월           0
# 일           0
# 전용면적        0
# 중개사소재지      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 3
# 오피스텔 매매
# ----------------------------------------------------------------------------------------------------
# 거래금액        0
# 거래유형        0
# 건축년도        0
# 년           0
# 단지          0
# 동리명         0
# 시군구         0
# 월           0
# 일           0
# 전용면적        0
# 중개사소재지      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 4
# 오피스텔 매매
# ----------------------------------------------------------------------------------------------------
# 거래금액        0
# 거래유형        0
# 건축년도        0
# 년           0
# 단지          0
# 동리명         0
# 시군구         0
# 월           0
# 일           0
# 전용면적        0
# 중개사소재지      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 5
# 오피스텔 매매
# ----------------------------------------------------------------------------------------------------
# 거래금액        0
# 거래유형        0
# 건축년도        0
# 년           0
# 단지          0
# 동리명         0
# 시군구         0
# 월           0
# 일           0
# 전용면적        0
# 중개사소재지      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 6
# 오피스텔 매매
# ----------------------------------------------------------------------------------------------------
# 거래금액        0
# 거래유형        0
# 건축년도        0
# 년           0
# 단지          0
# 동리명         0
# 시군구         0
# 월           0
# 일           0
# 전용면적        0
# 중개사소재지      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 7
# 오피스텔 매매
# ----------------------------------------------------------------------------------------------------
# 거래금액        0
# 거래유형        0
# 건축년도        0
# 년           0
# 단지          0
# 동리명         0
# 시군구         0
# 월           0
# 일           0
# 전용면적        0
# 중개사소재지      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 8
# 오피스텔 매매
# ----------------------------------------------------------------------------------------------------
# 거래금액        0
# 거래유형        0
# 건축년도        0
# 년           0
# 단지          0
# 동리명         0
# 시군구         0
# 월           0
# 일           0
# 전용면적        0
# 중개사소재지      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 9
# 오피스텔 매매
# ----------------------------------------------------------------------------------------------------
# 거래금액        0
# 거래유형        0
# 건축년도        0
# 년           0
# 단지          0
# 동리명         0
# 시군구         0
# 월           0
# 일           0
# 전용면적        0
# 중개사소재지      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 10
# 오피스텔 매매
# ----------------------------------------------------------------------------------------------------
# 거래금액        0
# 거래유형        0
# 건축년도        0
# 년           0
# 단지          0
# 동리명         0
# 시군구         0
# 월           0
# 일           0
# 전용면적        0
# 중개사소재지      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 11
# 오피스텔 매매
# ----------------------------------------------------------------------------------------------------
# 거래금액        0
# 거래유형        0
# 건축년도        0
# 년           0
# 단지          0
# 동리명         0
# 시군구         0
# 월           0
# 일           0
# 전용면적        0
# 중개사소재지      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 0
# 오피스텔 전월세
# ----------------------------------------------------------------------------------------------------
# 갱신요구권사용     0
# 건축년도        0
# 계약구분        0
# 계약기간        0
# 년           0
# 단지          0
# 동리명         0
# 보증금         0
# 시군구         0
# 월           0
# 월세          0
# 일           0
# 전용면적        0
# 종전계약보증금     0
# 종전계약월세      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 1
# 오피스텔 전월세
# ----------------------------------------------------------------------------------------------------
# 갱신요구권사용     0
# 건축년도        0
# 계약구분        0
# 계약기간        0
# 년           0
# 단지          0
# 동리명         0
# 보증금         0
# 시군구         0
# 월           0
# 월세          0
# 일           0
# 전용면적        0
# 종전계약보증금     0
# 종전계약월세      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 2
# 오피스텔 전월세
# ----------------------------------------------------------------------------------------------------
# 갱신요구권사용     0
# 건축년도        0
# 계약구분        0
# 계약기간        0
# 년           0
# 단지          0
# 동리명         0
# 보증금         0
# 시군구         0
# 월           0
# 월세          0
# 일           0
# 전용면적        0
# 종전계약보증금     0
# 종전계약월세      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 3
# 오피스텔 전월세
# ----------------------------------------------------------------------------------------------------
# 갱신요구권사용     0
# 건축년도        0
# 계약구분        0
# 계약기간        0
# 년           0
# 단지          0
# 동리명         0
# 보증금         0
# 시군구         0
# 월           0
# 월세          0
# 일           0
# 전용면적        0
# 종전계약보증금     0
# 종전계약월세      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 4
# 오피스텔 전월세
# ----------------------------------------------------------------------------------------------------
# 갱신요구권사용     0
# 건축년도        0
# 계약구분        0
# 계약기간        0
# 년           0
# 단지          0
# 동리명         0
# 보증금         0
# 시군구         0
# 월           0
# 월세          0
# 일           0
# 전용면적        0
# 종전계약보증금     0
# 종전계약월세      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 5
# 오피스텔 전월세
# ----------------------------------------------------------------------------------------------------
# 갱신요구권사용     0
# 건축년도        0
# 계약구분        0
# 계약기간        0
# 년           0
# 단지          0
# 동리명         0
# 보증금         0
# 시군구         0
# 월           0
# 월세          0
# 일           0
# 전용면적        0
# 종전계약보증금     0
# 종전계약월세      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 6
# 오피스텔 전월세
# ----------------------------------------------------------------------------------------------------
# 갱신요구권사용     0
# 건축년도        0
# 계약구분        0
# 계약기간        0
# 년           0
# 단지          0
# 동리명         0
# 보증금         0
# 시군구         0
# 월           0
# 월세          0
# 일           0
# 전용면적        0
# 종전계약보증금     0
# 종전계약월세      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 7
# 오피스텔 전월세
# ----------------------------------------------------------------------------------------------------
# 갱신요구권사용     0
# 건축년도        0
# 계약구분        0
# 계약기간        0
# 년           0
# 단지          0
# 동리명         0
# 보증금         0
# 시군구         0
# 월           0
# 월세          0
# 일           0
# 전용면적        0
# 종전계약보증금     0
# 종전계약월세      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 8
# 오피스텔 전월세
# ----------------------------------------------------------------------------------------------------
# 갱신요구권사용     0
# 건축년도        0
# 계약구분        0
# 계약기간        0
# 년           0
# 단지          0
# 동리명         0
# 보증금         0
# 시군구         0
# 월           0
# 월세          0
# 일           0
# 전용면적        0
# 종전계약보증금     0
# 종전계약월세      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 9
# 오피스텔 전월세
# ----------------------------------------------------------------------------------------------------
# 갱신요구권사용     0
# 건축년도        0
# 계약구분        0
# 계약기간        0
# 년           0
# 단지          0
# 동리명         0
# 보증금         0
# 시군구         0
# 월           0
# 월세          0
# 일           0
# 전용면적        0
# 종전계약보증금     0
# 종전계약월세      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 10
# 오피스텔 전월세
# ----------------------------------------------------------------------------------------------------
# 갱신요구권사용     0
# 건축년도        0
# 계약구분        0
# 계약기간        0
# 년           0
# 단지          0
# 동리명         0
# 보증금         0
# 시군구         0
# 월           0
# 월세          0
# 일           0
# 전용면적        0
# 종전계약보증금     0
# 종전계약월세      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 11
# 오피스텔 전월세
# ----------------------------------------------------------------------------------------------------
# 갱신요구권사용     0
# 건축년도        0
# 계약구분        0
# 계약기간        0
# 년           0
# 단지          0
# 동리명         0
# 보증금         0
# 시군구         0
# 월           0
# 월세          0
# 일           0
# 전용면적        0
# 종전계약보증금     0
# 종전계약월세      0
# 지번          0
# 법정동시군구코드    0
# 층           0
# 시도명         0
# 시군구명        0
# 주소          0
# 법정동코드       0
# 법정동읍면동코드    0
# geometry    0
# dtype: int64
#
# 실행 시간: 24.631996393203735 초

# %%
# import time

# # 실행 전 시간 기록
# start_time = time.time()

# # 국토교통부 데이터 세트
# list_nm =['apt_trade','apt_rent','offi_trade','offi_rent']

# # 4개 데이터 세트 반복문
# for i in range(len(list_nm)):
    
#     total = pd.DataFrame()
    
#     # 각 타입별 모든 데이터 조회
#     dir_list = windows_path + f'/0_data/{list_nm[i]}/*.csv'
#     file_list = sorted(glob.glob(dir_list))
    
#     for k in range(file_list):
#         print(k)
#         df = pd.read_csv(file_list[k], thousands=r',')
        
#         clean_df = molit_data_cleaning(df)
#         clean_df = clean_df.drop(columns=['geometry'])
        
#         total = pd.concat([total,clean_df])
        
#     file_name = windows_path + f'/0_data/cleaning/{list_nm[i]}.csv'
#     total.to_csv(file_name, index = False)
    
# # 실행 시간 계산
# execution_time = end_time - start_time
# print(f"실행 시간: {execution_time} 초")
