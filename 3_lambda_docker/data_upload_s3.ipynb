# %%
import pandas as pd
import glob
import os
import boto3

# 윈도우즈 경로
windows_path = r'C:\Users\ghdau\Desktop\real_estate_dashboard\0_data\streamlit_data'
# 리눅스 경로로 변환
linux_path = windows_path.replace('\\', '/')

# 현재 플랫폼에 따른 파일 경로 생성
if os.name == 'nt':  # 윈도우 플랫폼
    path = linux_path
    print('Window')
    
else:  # 리눅스나 다른 플랫폼
    path = '/home/ubuntu/real_estate_dashboard/0_data/streamlit_data'
    print('Linux')
    
# 작업 디렉토리 변경
os.chdir(path)

print(os.getcwd())
# Out:
# Linux
# /home/ubuntu/real_estate_dashboard/0_data/streamlit_data

# %%
# Key 
AWS_ACCESS_KEY_id = 'AKIA5ZPWZPVBXPIUH6U2'
AWS_ACCESS_KEY_SECRET = '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'

# Set AWS credentials
s3r = boto3.resource('s3',
                     aws_access_key_id = AWS_ACCESS_KEY_id,
                     aws_secret_access_key=AWS_ACCESS_KEY_SECRET)                     
bucket = s3r.Bucket('real-estate555-bucket')

file_list = glob.glob('**', recursive=True)
file_list
# Out:
# ['high_school.csv',
#  'apt_trade',
#  'apt_trade/apt_trade_202112.csv',
#  'apt_trade/apt_trade_202106.csv',
#  'apt_trade/apt_trade_202103.csv',
#  'apt_trade/apt_trade_202102.csv',
#  'apt_trade/apt_trade_202108.csv',
#  'apt_trade/apt_trade_202107.csv',
#  'apt_trade/apt_trade_202101.csv',
#  'apt_trade/apt_trade_202104.csv',
#  'apt_trade/apt_trade_202110.csv',
#  'apt_trade/apt_trade_202109.csv',
#  'apt_trade/apt_trade_202111.csv',
#  'apt_trade/apt_trade_202105.csv',
#  'elementary_school.csv',
#  'offi_rent_202311.csv',
#  'middle_school.csv',
#  'offi_rent',
#  'offi_rent/offi_rent_202101.csv',
#  'offi_rent/offi_rent_202111.csv',
#  'offi_rent/offi_rent_202103.csv',
#  'offi_rent/offi_rent_202109.csv',
#  'offi_rent/offi_rent_202106.csv',
#  'offi_rent/offi_rent_202112.csv',
#  'offi_rent/offi_rent_202102.csv',
#  'offi_rent/offi_rent_202108.csv',
#  'offi_rent/offi_rent_202104.csv',
#  'offi_rent/offi_rent_202107.csv',
#  'offi_rent/offi_rent_202110.csv',
# ...

# %%
for file_name in file_list:
    file_name_2 = f'0_data/streamlit_data/{file_name}'
    
    if(file_name in ['apt_trade','apt_rent','offi_trade','offi_rent']):
        continue
        
    bucket.upload_file(file_name, file_name_2)
    print(file_name)
# Out:
# high_school.csv
# apt_trade/apt_trade_202112.csv
# apt_trade/apt_trade_202106.csv
# apt_trade/apt_trade_202103.csv
# apt_trade/apt_trade_202102.csv
# apt_trade/apt_trade_202108.csv
# apt_trade/apt_trade_202107.csv
# apt_trade/apt_trade_202101.csv
# apt_trade/apt_trade_202104.csv
# apt_trade/apt_trade_202110.csv
# apt_trade/apt_trade_202109.csv
# apt_trade/apt_trade_202111.csv
# apt_trade/apt_trade_202105.csv
# elementary_school.csv
# offi_rent_202311.csv
# middle_school.csv
# offi_rent/offi_rent_202101.csv
# offi_rent/offi_rent_202111.csv
# offi_rent/offi_rent_202103.csv
# offi_rent/offi_rent_202109.csv
# offi_rent/offi_rent_202106.csv
# offi_rent/offi_rent_202112.csv
# offi_rent/offi_rent_202102.csv
# offi_rent/offi_rent_202108.csv
# offi_rent/offi_rent_202104.csv
# offi_rent/offi_rent_202107.csv
# offi_rent/offi_rent_202110.csv
# offi_rent/offi_rent_202105.csv
# apt_trade_202311.csv
# offi_trade_202311.csv
# apt_rent_202311.csv
# offi_trade/offi_trade_202104.csv
# ...
